# %% [markdown]
# <a name = "inicio"></a>
# ![image.png](attachment:image.png)

# %% [markdown]
# <div style="font-size: 50px;text-align: center;height:60px;padding:10px;margin:10px 0 0 0;">Word2Vec</div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### orange oranges are good, green oranges are not

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# *Fuente: "Efficient Estimation of Word Representations in Vector Space", Tomas Mikolov et al. https://arxiv.org/pdf/1301.3781.pdf*

# %% [markdown]
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>
