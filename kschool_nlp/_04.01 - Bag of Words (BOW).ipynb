# %% [markdown]
# <a name = "inicio"></a>
# ![image.png](attachment:image.png)

# %% [markdown]
# <div style="font-size: 50px;text-align: center;height:60px;padding:10px;margin:10px 0 0 0;">Bag of Words (BOW)</div>

# %%
raw_corpus = [
    "the sun is yellow, not orange",
    "the orange is orange",
    "the sky is blue, not yellow",
    "I eat a yellow orange and a yellow sky",
    "the orange isn't blue but I eat it",
    "my green orange is good",
    "I don't eat blue oranges",
    "bananas are bananas"
]

# %% [markdown]
# # Preprocesamiento de los datos

# %% [markdown]
# # Generación de la matrix BOW

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html

# %% [markdown]
# # Parámetros

# %% [markdown]
# # Atributos

# %% [markdown]
# # Aplicación a nuevos datos

# %%
new_raw_corpus = [
    "the sky is not red",
    "my green orange is bad"
]

# %% [markdown]
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>
